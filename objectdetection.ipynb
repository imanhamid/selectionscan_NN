# %% [markdown]
# # Object Detection Notebook using IceVision

# %% [markdown]
# Using Singularity container w/ IceVision v0.5.2 (https://airctic.com/0.5.2/)

# %%
from icevision.all import *
import pandas as pd
import numpy as np

# %%
#set directories
root_dir = "/work/ih49/simulations/"
base_dir = root_dir + 'AIMs/'

#testing run on full ancestry images
path = Path(base_dir + 'full_ancestry/')

# %%
fnames = get_image_files(path)

# %% [markdown]
# Calculate bounding box vertices as 5 pixels +/- the variant position. Variant location (physical position) is taken from the image file name, and converted to pixel coordinates.
#
# Bbox is formated as \[xmin, ymin, xmax, ymax\], with indices started at 0 from the bottom left corner.

# %%
pos = [int(re.search("pos-(.*)_seed", str(i)).group(1)) for i in fnames]
bbox_xmin = [math.ceil((i / 50e6) * 200) - 5 for i in pos]
labl_bbox = [[i, 0, i + 11, 200] for i in bbox_xmin]
image_id = [re.search("(.*.png)", str(i)).group(1) for i in fnames]

# %% [markdown]
# Combine image filename, image width, image height, bbox, and source \[which is the "images" directory\] in dataframe (for input to icevision parser).

# %%
df = pd.DataFrame(list(zip(image_id, [200] * len(image_id), [200] * len(image_id), labl_bbox, [str(path) for i in image_id])), 
               columns =['image_id', 'width', 'height', 'bbox', 'source'])

# %% [markdown]
# Creat custom parser. I followed [this tutorial](https://airctic.com/0.5.2/custom_parser/) with some modifications.

# %%
class VariantParser(parsers.Parser, parsers.FilepathMixin, parsers.LabelsMixin, parsers.BBoxesMixin):
    pass

# %%
VariantParser.generate_template()
# Out:
# def __iter__(self) -> Any:
# def imageid(self, o) -> Hashable:
# def image_width_height(self, o) -> Tuple[int, int]:
#     return get_image_size(self.filepath(o))
# def filepath(self, o) -> Union[str, Path]:
# def bboxes(self, o) -> List[BBox]:
# def labels(self, o) -> List[int]:

# %%
class VariantParser(parsers.FasterRCNN, parsers.FilepathMixin, parsers.SizeMixin):
    def __init__(self, df, source):
        self.df = df
        self.source = source

    def __iter__(self):
        yield from self.df.itertuples()

    def __len__(self):
        return len(self.df)

    def imageid(self, o) -> Hashable:
        return o.image_id

    def filepath(self, o) -> Union[str, Path]:
        return self.source / f"{o.image_id}"

    def image_width_height(self, o) -> Tuple[int, int]:
        return get_image_size(self.filepath(o))

    def labels(self, o) -> List[int]:
        return [1]

    def bboxes(self, o) -> List[BBox]:
        return [BBox.from_xyxy(*np.fromiter(o.bbox, dtype="int"))]

# %% [markdown]
# Create class map. This is necessary, even though there is only one class.

# %%
class_map = ClassMap(['selected_variant'])

# %% [markdown]
# Split data to training and validation records. I set a random seed so we can be comparing with the same train/valid sets. 8000 images in training set, 2000 in validation set.
#
# This may take a couple minutes to run.

# %%
parser = VariantParser(df, path)
train_rs, valid_rs = parser.parse(data_splitter=RandomSplitter([0.8, 0.2], seed=42))
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO     - Autofixing records | icevision.parsers.parser:parse:126
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2678  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5547  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2304  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 107  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7770  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7539  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1862  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1123  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 119  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7791  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1068  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3817  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9412  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3898  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8076  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7807  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7821  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9420  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3834  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9701  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 794  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7618  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7642  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7093  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1408  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5795  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4721  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3541  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3837  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8720  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4812  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4983  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8174  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5050  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5572  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3526  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 76  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6100  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4080  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6918  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9039  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7144  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2075  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 543  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8757  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4734  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8729  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4102  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3130  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1330  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8283  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1360  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9340  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 850  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4475  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5521  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6631  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8279  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 872  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8728  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 461  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7086  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3025  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9410  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5193  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6454  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6800  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8581  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7750  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2701  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6440  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8492  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9525  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3053  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2335  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3782  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7162  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1880  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5945  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7793  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1688  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 745  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2221  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2088  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5728  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2122  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2225  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2362  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6486  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6571  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 591  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 185  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7430  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7855  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8218  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6989  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 467  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 927  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3325  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7091  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8440  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2955  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3649  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 605  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5613  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 724  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 533  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6412  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5244  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4961  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7912  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7963  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3522  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 618  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5963  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1918  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6079  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7917  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1840  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3538  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 411  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5135  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7153  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 821  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2272  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 81  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5339  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3720  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2373  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9444  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8688  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5780  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3518  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1027  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1978  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8920  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3785  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7927  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 779  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 835  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3378  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9621  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6322  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4007  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6618  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4429  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1844  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7382  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3111  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5407  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7716  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3548  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4060  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9041  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5112  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 773  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9110  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6127  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5694  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5186  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9242  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3635  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5705  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3307  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1465  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9401  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8371  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8182  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6846  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 26  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2706  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9914  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9618  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4560  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4598  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2579  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4726  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3945  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6390  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4792  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8876  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8957  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6215  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8648  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9616  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1722  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8796  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 565  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8417  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5199  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9105  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 734  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6642  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7928  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2314  ️🔨 | icevision.core.record:_pre_replay:89
# ...
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4566  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7776  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3310  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7221  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8519  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2717  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4971  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1792  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9388  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8389  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7577  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5415  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -4 to 0 (Before: <BBox (xmin:-4, ymin:0, xmax:7, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2635  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9111  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9305  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8172  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 918  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4143  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6493  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6031  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4530  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4858  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8580  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7939  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2871  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5713  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 924  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2779  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6588  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9348  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6541  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7651  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2504  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2738  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 851  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 202 to image width 200 (Before: <BBox (xmin:191, ymin:0, xmax:202, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5878  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 8527  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4611  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 559  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1148  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 1409  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3327  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5600  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7022  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 225  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5895  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5699  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 205 to image width 200 (Before: <BBox (xmin:194, ymin:0, xmax:205, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2869  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6197  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4548  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 203 to image width 200 (Before: <BBox (xmin:192, ymin:0, xmax:203, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9561  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3696  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -2 to 0 (Before: <BBox (xmin:-2, ymin:0, xmax:9, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5232  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 4636  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6892  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 7385  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 6184  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5618  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 206 to image width 200 (Before: <BBox (xmin:195, ymin:0, xmax:206, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 2027  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5276  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -1 to 0 (Before: <BBox (xmin:-1, ymin:0, xmax:10, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 3843  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmin from -3 to 0 (Before: <BBox (xmin:-3, ymin:0, xmax:8, ymax:200)>) | icevision.core.bbox:autofix:63
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 9555  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 204 to image width 200 (Before: <BBox (xmin:193, ymin:0, xmax:204, ymax:200)>) | icevision.core.bbox:autofix:77
# AUTOFIX-START - ️🔨  Autofixing record with imageid: 5390  ️🔨 | icevision.core.record:_pre_replay:89
# AUTOFIX-SUCCESS - Clipping bbox xmax from 201 to image width 200 (Before: <BBox (xmin:190, ymin:0, xmax:201, ymax:200)>) | icevision.core.bbox:autofix:77

# %% [markdown]
# Make sure everything looks correct.

# %%
show_record(train_rs[60], display_label=False)

# %%
len(train_rs), len(valid_rs)
# Out:
# (8000, 2000)

# %%
train_ds = Dataset(train_rs)
valid_ds = Dataset(valid_rs)

# %% [markdown]
# Create dataloaders and define the model we're using ([FasterRCNN](https://airctic.com/0.5.2/model_faster_rcnn/), resnet18 architecture)

# %%
train_dl = faster_rcnn.train_dl(train_ds, batch_size=16, num_workers=4, shuffle=True)
valid_dl = faster_rcnn.valid_dl(valid_ds, batch_size=16, num_workers=4, shuffle=False)

# %%
backbone = faster_rcnn.backbones.resnet_fpn.resnet18(pretrained=True)
model = faster_rcnn.model(backbone=backbone, num_classes=len(class_map))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /hpc/home/ih49/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# Define custom metrics & wrap in Metric class
#
# * Center proportion (center_metric) = proportion of predicted bboxes that contain the selected variant. (should be close to 1)
# * Average width (width_metric) = average width of bboxes (should be ~11 pixels wide)
# * Number of boxes (num_bboxes) = average number of predicted bboxes per image (should be close to 1)

# %%
def center_metric(sample, pred):
  bbox_pred = pred['bboxes']
  if len(bbox_pred)>0:
    bbox_xaxis_pred = [i.xyxy[0:3:2] for i in bbox_pred]
    bbox_sample = sample['bboxes'][0]
    bbox_xaxis_sample = bbox_sample.xyxy[0:3:2]
    sample_midpoint = math.ceil((bbox_xaxis_sample[0] + bbox_xaxis_sample[1])/2)
    center_in_bbox = [i[1] >= sample_midpoint >= i[0] for i in bbox_xaxis_pred]
    center_accuracy_mean = np.mean(center_in_bbox)
  else:
    center_accuracy_mean = 0
  return center_accuracy_mean

def width_metric(pred):
  bbox_pred = pred['bboxes']
  if len(bbox_pred)>0:
    bbox_xaxis_pred = [i.xyxy[0:3:2] for i in bbox_pred]
    pred_width = [i[1] - i[0] for i in bbox_xaxis_pred]
    pred_width_mean = np.mean(pred_width)
  else:
    pred_width_mean = None
  return pred_width_mean
  

def num_bboxes(pred):
  num_boxes = len(pred['bboxes'])
  return num_boxes

# %% [markdown]
# For all metrics, the idea here is to calculate the metric for all validation records (2000 images) and collect them by batches (accumulate), and average across all records at the end of each epoch (finalize). Then, the accumulated metrics need to be cleared at the end of each epoch so that they can be calculated anew the next cycle.
#
# For average widths: some records will have no predicted bboxes, so the average is not calculated for those values. That is, we calculate the average width only for those bboxes that are predicted. So the denominator may be more or less than the actual number of valiation records. This value will likely be None in the first epoch because no bboxes will be predicted.

# %%
class Center_Proportion(Metric):
    def __init__(self):
        self._props = []

    def _reset(self):
        self._props.clear()

    def accumulate(self, records, preds):
        center_results = [center_metric(sample, pred) for sample, pred in zip(records,preds)]
        self._props.extend(center_results)

    def finalize(self) -> Dict[str, float]:
        final_prop = np.mean(self._props)
        self._reset()
        return {'Center_in_Bbox': final_prop}

class Avg_Width(Metric):
    def __init__(self):
        self._widths = []

    def _reset(self):
        self._widths.clear()

    def accumulate(self, records, preds):
        width_results = [width_metric(pred) for pred in preds]
        for i in width_results:
          if i:
            self._widths.append(i)
          else:
            pass

    def finalize(self) -> Dict[str, float]:
        if self._widths:
          final_avg = np.mean(self._widths)
        else:
          final_avg = None
        self._reset()
        return {'Width_Bbox': final_avg}

class Num_Bboxes(Metric):
    def __init__(self):
        self._num = []

    def _reset(self):
        self._num.clear()

    def accumulate(self, records, preds):
        num_boxes_results = [num_bboxes(pred) for pred in preds]
        self._num.extend(num_boxes_results)

    def finalize(self) -> Dict[str, float]:
        final_num = np.mean(self._num)
        self._reset()
        return {'Num_Bbox': final_num}

# %% [markdown]
# ### Training the model (skip this section if loading existing weights!)

# %% [markdown]
# Define the fastai learner, specifying metrics. I included COCOMetric(), which is commonly used for bboxes. It is essentialy IoU.
#
# We could also use PyTorch Lightening instead of FastAI, but I'm sticking with FastAI since we're familiar with it.

# %%
metrics = [COCOMetric(), Num_Bboxes(), Center_Proportion(), Avg_Width()]
learn = faster_rcnn.fastai.learner(
    dls=[train_dl, valid_dl], model=model, metrics=metrics
)

# %% [markdown]
# Keep in mind that metric values don't seem to match the true values when we export the model and infer/predict on our validation set. I'm still not clear why the numbers don't match.
#
# This will take ~10-15 min to train for 1k images (may also depend on your node/available mem?). For 10k images, it took ~1.5 hours.

# %%
learn.fine_tune(30, base_lr=3e-3, freeze_epochs=1, wd=1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>COCOMetric</th>
#       <th>Num_Bboxes</th>
#       <th>Center_Proportion</th>
#       <th>Avg_Width</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.029627</td>
#       <td>2.029460</td>
#       <td>0.000000</td>
#       <td>0.002500</td>
#       <td>0.000000</td>
#       <td>46.61363</td>
#       <td>02:24</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>COCOMetric</th>
#       <th>Num_Bboxes</th>
#       <th>Center_Proportion</th>
#       <th>Avg_Width</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.130624</td>
#       <td>0.129607</td>
#       <td>0.519431</td>
#       <td>2.379500</td>
#       <td>0.840936</td>
#       <td>12.053602</td>
#       <td>02:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.105377</td>
#       <td>0.092636</td>
#       <td>0.596567</td>
#       <td>2.434000</td>
#       <td>0.841644</td>
#       <td>11.067623</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.094149</td>
#       <td>0.082151</td>
#       <td>0.621836</td>
#       <td>2.315000</td>
#       <td>0.845455</td>
#       <td>10.808065</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.078728</td>
#       <td>0.084772</td>
#       <td>0.661749</td>
#       <td>3.381000</td>
#       <td>0.826045</td>
#       <td>10.939859</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.075775</td>
#       <td>0.069801</td>
#       <td>0.633235</td>
#       <td>3.259500</td>
#       <td>0.833658</td>
#       <td>10.363561</td>
#       <td>03:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.070085</td>
#       <td>0.065788</td>
#       <td>0.664353</td>
#       <td>1.992500</td>
#       <td>0.888759</td>
#       <td>10.727402</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.077469</td>
#       <td>0.070010</td>
#       <td>0.639011</td>
#       <td>2.183000</td>
#       <td>0.857760</td>
#       <td>10.536894</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.063978</td>
#       <td>0.066965</td>
#       <td>0.638778</td>
#       <td>1.393000</td>
#       <td>0.922324</td>
#       <td>10.750382</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.061468</td>
#       <td>0.058606</td>
#       <td>0.649130</td>
#       <td>1.802000</td>
#       <td>0.902285</td>
#       <td>10.611019</td>
#       <td>02:58</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.064898</td>
#       <td>0.057421</td>
#       <td>0.673584</td>
#       <td>1.530000</td>
#       <td>0.926426</td>
#       <td>11.104535</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.075858</td>
#       <td>0.098732</td>
#       <td>0.690147</td>
#       <td>4.526500</td>
#       <td>0.740615</td>
#       <td>10.960451</td>
#       <td>03:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.066447</td>
#       <td>0.063833</td>
#       <td>0.672796</td>
#       <td>2.536500</td>
#       <td>0.847091</td>
#       <td>10.950739</td>
#       <td>02:58</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.065801</td>
#       <td>0.065951</td>
#       <td>0.663385</td>
#       <td>2.832000</td>
#       <td>0.805805</td>
#       <td>10.879716</td>
#       <td>02:55</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.064888</td>
#       <td>0.063995</td>
#       <td>0.665197</td>
#       <td>2.465000</td>
#       <td>0.834057</td>
#       <td>10.888359</td>
#       <td>02:54</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.049950</td>
#       <td>0.124374</td>
#       <td>0.679073</td>
#       <td>1.974500</td>
#       <td>0.905929</td>
#       <td>10.956171</td>
#       <td>02:55</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.048755</td>
#       <td>0.052684</td>
#       <td>0.678842</td>
#       <td>2.165000</td>
#       <td>0.879598</td>
#       <td>10.968513</td>
#       <td>02:56</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.048910</td>
#       <td>0.049957</td>
#       <td>0.701188</td>
#       <td>2.619000</td>
#       <td>0.879501</td>
#       <td>10.974205</td>
#       <td>02:54</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.046120</td>
#       <td>0.051236</td>
#       <td>0.713995</td>
#       <td>1.921500</td>
#       <td>0.912883</td>
#       <td>11.079132</td>
#       <td>02:55</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.042872</td>
#       <td>0.050982</td>
#       <td>0.681735</td>
#       <td>1.497000</td>
#       <td>0.927797</td>
#       <td>10.777027</td>
#       <td>02:56</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.042659</td>
#       <td>0.047434</td>
#       <td>0.708036</td>
#       <td>1.781500</td>
#       <td>0.922334</td>
#       <td>10.859369</td>
#       <td>02:55</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.042864</td>
#       <td>0.047867</td>
#       <td>0.691562</td>
#       <td>1.737500</td>
#       <td>0.909294</td>
#       <td>10.835369</td>
#       <td>02:53</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.039742</td>
#       <td>0.073440</td>
#       <td>0.700712</td>
#       <td>1.861000</td>
#       <td>0.924596</td>
#       <td>10.784163</td>
#       <td>02:54</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.038470</td>
#       <td>0.053216</td>
#       <td>0.680076</td>
#       <td>1.652500</td>
#       <td>0.933093</td>
#       <td>10.890374</td>
#       <td>02:54</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.032238</td>
#       <td>0.140447</td>
#       <td>0.714485</td>
#       <td>1.626000</td>
#       <td>0.933919</td>
#       <td>10.865263</td>
#       <td>02:56</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.036305</td>
#       <td>0.113515</td>
#       <td>0.698318</td>
#       <td>1.790000</td>
#       <td>0.923959</td>
#       <td>10.82197</td>
#       <td>02:53</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.033314</td>
#       <td>0.086450</td>
#       <td>0.695389</td>
#       <td>1.591500</td>
#       <td>0.931675</td>
#       <td>10.797563</td>
#       <td>02:54</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.029686</td>
#       <td>0.106570</td>
#       <td>0.695848</td>
#       <td>1.451500</td>
#       <td>0.934673</td>
#       <td>10.829184</td>
#       <td>02:55</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.029930</td>
#       <td>0.132546</td>
#       <td>0.693576</td>
#       <td>1.444000</td>
#       <td>0.938215</td>
#       <td>10.798668</td>
#       <td>02:53</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.027201</td>
#       <td>0.170364</td>
#       <td>0.693858</td>
#       <td>1.367500</td>
#       <td>0.939859</td>
#       <td>10.821993</td>
#       <td>02:53</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.027646</td>
#       <td>0.176976</td>
#       <td>0.694448</td>
#       <td>1.355000</td>
#       <td>0.940187</td>
#       <td>10.813624</td>
#       <td>02:55</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Run inference on the validation set. Confirm accuracy with each of the relevant metrics.

# %%
infer_dl = faster_rcnn.infer_dl(valid_ds, batch_size=16)
samples, preds = faster_rcnn.predict_dl(model, infer_dl)
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]

# %%
center_results = [center_metric(sample, pred) for sample, pred in zip(samples,preds)]
num_boxes_results = [num_bboxes(pred) for pred in preds]
width_results = [width_metric(pred) for pred in preds]
final_widths = []
for i in width_results:
    if i:
      final_widths.append(i)
    else:
      pass
np.mean(center_results), np.mean(num_boxes_results), np.mean(final_widths)
# Out:
# (0.95, 1.027, 10.825825)

# %% [markdown]
# Pretty good! We're averaging 1 predicted bounding box per image, the variant is detected w/in the bounding boxes for ~95% of validation images, and the average bounding box has a width of ~11 pixels!
#
# (Earlier note: w/ the 25 megabase s=0.05 images (1k total), I trained this exact same model 3 times to confirm, and the avg center proportion metric is 90.6%, num boxes ~1.02, and avg box width ~10.83 pixels. These results were consistent and had low variance across the three replicates, so I'm fairly confident you should get approximately the same accuracy in training.)
#
# Only trained once for this larger dataset

# %%
show_preds(samples[:6], preds[:6], class_map, display_label=False, display_mask=False)

# %% [markdown]
# Save the model weights so we can reload them later! Good so we can recalculate performance metrics without having to retrain the model. **Make sure not to save over an existing model weight file!!**

# %%
torch.save(model.state_dict(), 'object_localization_full-ancestry.model.pth')

# %% [markdown]
# Save the predictions and targets as well. Predictions includes a score (can interpret as posterior probability), but only reports predictions with the score above the threshold (which is 0.5). I haven't figured out how to change the prediction threshhold so we could get a true ROC or Precision-Recall curve... Even then, the prediction score will be for the whole bbox, not each individual x-axis position...

# %%
pd.DataFrame(preds).to_csv("object_localization_full_ancestry_preds.txt", sep='\t', header=True, index=False)

# %%
pd.DataFrame(samples).to_csv("object_localization_full_ancestry_targets.txt", sep='\t', header=True, index=False, columns=['imageid','bboxes','labels','filepath'])

# %% [markdown]
# ### Skip training and start here to load model weights!

# %%
model2 = faster_rcnn.model(backbone=backbone, num_classes=len(class_map))
model2.load_state_dict(torch.load('object_localization_full-ancestry.model.pth', map_location=torch.device('cuda')))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Make sure results are the same when loading the pretrained weights.

# %%
samples2, preds2 = faster_rcnn.predict_dl(model2.cuda(), infer_dl)
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]

# %%
center_results = [center_metric(sample, pred) for sample, pred in zip(samples2,preds2)]
num_boxes_results = [num_bboxes(pred) for pred in preds2]
width_results = [width_metric(pred) for pred in preds2]
final_widths = []
for i in width_results:
    if i:
      final_widths.append(i)
    else:
      pass
np.mean(center_results), np.mean(num_boxes_results), np.mean(final_widths)
# Out:
# (0.95, 1.027, 10.825825)

# %%
show_preds(samples[:6], preds[:6], class_map, display_label=False, display_mask=False)

# %% [markdown]
# Looking good!!!!
